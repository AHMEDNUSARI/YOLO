# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9

# %%
# %cd {HOME}/yolov9  
# !python train_dual.py \
--batch 8 --epochs 50 --img 320 --device 0 --min-items 0 --close-mosaic 15 --name accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml \
--weights  /home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt \
--cfg   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml \
--hyp  /home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# train_dual: weights=/home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt, cfg=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml, data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml, hyp=/home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml, epochs=200, batch_size=8, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=accedent, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
# %cd {HOME}/yolov9  
# !python train_dual.py \
--batch 16 --epochs 50 --img 320 --device 0 --min-items 0 --close-mosaic 15 --name accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml \
--weights  /home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt \
--cfg   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml \
--hyp  /home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# train_dual: weights=/home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt, cfg=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml, data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml, hyp=/home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml, epochs=50, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=accedent, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
from IPython.display import Image
Image(filename=f"/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/accedent4/confusion_matrix.png", width=1000)

# %%
# %cd {HOME}/yolov9  
# !python train_dual.py \
--batch 16 --epochs 60 --img 320 --device 0 --min-items 0 --close-mosaic 15 --name accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml \
--weights  /home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-e.pt \
--cfg   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-e.yaml \
--hyp  /home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# train_dual: weights=/home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-e.pt, cfg=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-e.yaml, data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml, hyp=/home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml, epochs=60, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=accedent, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
from IPython.display import Image
Image(filename=f"/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/accedent5/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/accedent4/results.png", width=1000)

# %%
# %cd {HOME}/yolov9


# !python /home/derin2/Desktop/Yolo/YOLOv9/yolov9/detect.py \--img 320 --weights /home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/accedent5/weights/best.pt --conf 0.1 --source /home/derin2/Desktop/Yolo/YOLONAS --device 0
# Out:
# [Errno 2] No such file or directory: '{HOME}/yolov9'
# /home/derin2/Desktop/Yolo/YOLOv9
# detect: weights=['/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/accedent5/weights/best.pt'], source=/home/derin2/Desktop/Yolo/YOLONAS, data=yolov9/data/coco128.yaml, imgsz=[320, 320], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.0 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# yolov9-e summary: 1119 layers, 69349868 parameters, 0 gradients, 243.3 GFLOPs
# image 1/1 /home/derin2/Desktop/Yolo/YOLONAS/pred_0.jpg: 320x320 1 severe, 23.9ms
# ...

# %%
# %cd {HOME}/yolov9  
# !python train_dual.py \
--batch 8 --epochs 60 --img 320 --device 0,1 --min-items 0 --close-mosaic 15 --name New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml \
--weights  /home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-e.pt \
--cfg   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-e.yaml \
--hyp  /home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# train_dual: weights=/home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-e.pt, cfg=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-e.yaml, data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml, hyp=/home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml, epochs=60, batch_size=8, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=New_accedent, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
# %cd {HOME}/yolov9  
# !python val_dual.py \
--batch 8  --img 320 --device 0 --min-items 0  --name ValF_E_New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml \
--weights /home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/New_accedent2/weights/best.pt
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# val_dual: data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml, weights=['/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/New_accedent2/weights/best.pt'], batch_size=8, imgsz=320, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=ValF_E_New_accedent, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.9.19 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# yolov9-e summary: 1119 layers, 69349868 parameters, 0 gradients, 243.3 GFLOPs
# val: Scanning /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/t
#                  Class     Images  Instances          P          R      mAP50
#                    all        649        650      0.937      0.941      0.979      0.938
# ...

# %%
# %cd {HOME}/yolov9  
# !python train_dual.py \
--batch 8 --epochs 60 --img 320 --device 0 --min-items 0 --close-mosaic 15 --name C_New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml \
--weights  /home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt \
--cfg   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml \
--hyp  /home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# train_dual: weights=/home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt, cfg=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml, data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml, hyp=/home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml, epochs=60, batch_size=8, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=C_New_accedent, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
# %cd {HOME}/yolov9  
# !python val_dual.py \
--batch 8  --img 320 --device 0 --min-items 0  --name ValF_C_New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml \
--weights /home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/C_New_accedent/weights/best.pt
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# val_dual: data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml, weights=['/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/C_New_accedent/weights/best.pt'], batch_size=8, imgsz=320, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=ValF_C_New_accedent, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.9.19 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# yolov9-c summary: 724 layers, 50960940 parameters, 0 gradients, 237.7 GFLOPs
# val: Scanning /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/t
#                  Class     Images  Instances          P          R      mAP50
#                    all        649        650      0.963      0.937      0.968      0.935
# ...

# %%
# %cd {HOME}/yolov9  
# !python train_dual.py \
--batch 16 --epochs 120 --img 320 --device 0 --min-items 0 --patience 30 --close-mosaic 15 --name CS_New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml \
--weights  /home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt \
--cfg   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml \
--hyp  /home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# train_dual: weights=/home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-c.pt, cfg=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-c.yaml, data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml, hyp=/home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml, epochs=120, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=CS_New_accedent, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=30, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
# %cd {HOME}/yolov9  
# !python val_dual.py \
--batch 16  --img 320 --device 0 --min-items 0  --name ValCS_New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml \
--weights /home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/CS_New_accedent3/weights/best.pt \
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# val_dual: data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml, weights=['/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/CS_New_accedent3/weights/best.pt'], batch_size=16, imgsz=320, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=ValCS_New_accedent, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.9.19 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# yolov9-c summary: 724 layers, 50960940 parameters, 0 gradients, 237.7 GFLOPs
# val: Scanning /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/t
# val: New cache created: /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/test/labels.cache
# ...

# %%
# %cd {HOME}/yolov9  
# !python train_dual.py \
--batch 16 --epochs 120 --img 320 --device 0,1 --min-items 0 --patience 30 --close-mosaic 15 --name SE_New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml \
--weights  /home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-e.pt \
--cfg   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-e.yaml \
--hyp  /home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# train_dual: weights=/home/derin2/Desktop/Yolo/YOLOv9/weights/yolov9-e.pt, cfg=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/models/detect/yolov9-e.yaml, data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data.yaml, hyp=/home/derin2/Desktop/Yolo/YOLOv9/yolov9//data/hyps/hyp.scratch-high.yaml, epochs=120, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=SE_New_accedent, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=30, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
# %cd {HOME}/yolov9  
# !python val_dual.py \
--batch 8  --img 320 --device 0 --min-items 0  --name ValSE_New_accedent\
--data   /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml \
--weights /home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/SE_New_accedent/weights/best.pt \
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# val_dual: data=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/data_test.yaml, weights=['/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/SE_New_accedent/weights/best.pt'], batch_size=8, imgsz=320, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=ValSE_New_accedent, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.9.19 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# yolov9-e summary: 1119 layers, 69349868 parameters, 0 gradients, 243.3 GFLOPs
# val: Scanning /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/t
#                  Class     Images  Instances          P          R      mAP50
#                    all        649        650      0.977      0.904       0.97      0.941
# ...

# %%
# %cd {HOME}/yolov9


# !python /home/derin2/Desktop/Yolo/YOLOv9/yolov9/detect.py \--img 320 --weights /home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/accedent4/weights/best.pt --conf 0.1 --source /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/2/images --device 0
# Out:
# /home/derin2/Desktop/Yolo/YOLOv9/yolov9
# detect: weights=['/home/derin2/Desktop/Yolo/YOLOv9/yolov9/runs/train/accedent4/weights/best.pt'], source=/home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/2/images, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.0 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# yolov9-c summary: 724 layers, 50960940 parameters, 0 gradients, 237.7 GFLOPs
# image 1/6 /home/derin2/Desktop/Yolo/YOLOv9/yolov9/AccidentsDetectionYOLOv8/2/images/1107_jpeg_jpg.rf.33889099c7d14c60428b4618ff5953c5.jpg: 320x320 (no detections), 19.1ms
# ...
